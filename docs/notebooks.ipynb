# %% [markdown]
# # Content with notebooks
#
# You can also create content with Jupyter Notebooks. This means that you can include
# code blocks and their outputs in your book.

# %% [markdown]
# ## Funny content

# %% [markdown]
# ### Sidebar

# %% [markdown]
# ```{sidebar} My sidebar title
# My sidebar content
# ```

# %% [markdown]
# Let's try out some funny content...
#
# Let's try out some funny content...
#
# Let's try out some funny content...
#
# Let's try out some funny content...
#
# Let's try out some funny content...
#
# Let's try out some funny content...

# %% [markdown]
# ### Margin

# %% [markdown]
# ```{margin} An optional title
# My margin content
# ```

# %% [markdown]
# Let's try out some funny content...
#
# Let's try out some funny content...
#
# Let's try out some funny content...
#
# Let's try out some funny content...
#
# Let's try out some funny content...
#
# Let's try out some funny content...

# %% [markdown]
# ## Wide figures

# %%
import malariagen_data

# %%
ag3 = malariagen_data.Ag3(
    url="simplecache::gs://vo_agam_release",
    simplecache=dict(cache_storage="gcs_cache"),)
ag3
# Out:
# <MalariaGEN Ag3 API client>
# Storage URL             : simplecache::gs://vo_agam_release
# Data releases available : 3.0
# Results cache           : None
# Cohorts analysis        : 20220608
# Species analysis        : aim_20220528
# Site filters analysis   : dt_20200416
# Software version        : malariagen_data 7.1.3
# Client location         : England, GB
# ---
# Please note that data are subject to terms of use,
# for more information see https://www.malariagen.net/data
# or contact data@malariagen.net. For API documentation see
# https://malariagen.github.io/vector-data/ag3/api.html

# %%
ag3.sample_metadata(sample_sets="AG1000G-KE").head()
# Out:
# Load sample metadata:   0%|          | 0/1 [00:00<?, ?it/s]
#   sample_id partner_sample_id   contributor country location  year  month  \
# 0  AK0041-C             KIL52  Janet Midega   Kenya   Kilifi  2012     -1
# 1  AK0042-C             KIL53  Janet Midega   Kenya   Kilifi  2012     -1
# 2  AK0043-C             KIL54  Janet Midega   Kenya   Kilifi  2012     -1
# 3  AK0044-C             KIL55  Janet Midega   Kenya   Kilifi  2012     -1
# 4  AK0046-C             KIL35  Janet Midega   Kenya   Kilifi  2012     -1
#
#    latitude  longitude sex_call  ... aim_species country_iso  admin1_name  \
# 0    -3.511     39.909        F  ...  arabiensis         KEN       Kilifi
# 1    -3.511     39.909        F  ...  arabiensis         KEN       Kilifi
# 2    -3.511     39.909        F  ...  arabiensis         KEN       Kilifi
# 3    -3.511     39.909        F  ...  arabiensis         KEN       Kilifi
# 4    -3.511     39.909        F  ...  arabiensis         KEN       Kilifi
#
# ...

# %%
import bokeh.io

# %%
bokeh.io.output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
import numpy as np

from bokeh.plotting import figure, show

N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = np.array([ [r, g, 150] for r, g in zip(50 + 2*x, 30 + 2*y) ], dtype="uint8")

TOOLS="hover,crosshair,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select,help"

p1 = figure(tools=TOOLS, sizing_mode="stretch_width", height=300, width=600)

p1.scatter(x, y, radius=radii,
          fill_color=colors, fill_alpha=0.6,
          line_color=None)

show(p1)
# Out:
#   <div class="bk-root" id="e01f24b3-82ba-428f-81ab-b5293979907e" data-root-id="1476"></div>

# %% [markdown]
# Here it is again, is it linked?

# %%
N = 2000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = np.array([ [r, g, 150] for r, g in zip(50 + 2*x, 30 + 2*y) ], dtype="uint8")

TOOLS="hover,crosshair,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select,help"

p2 = figure(tools=TOOLS, sizing_mode="stretch_width", height=300, width=600, x_range=p1.x_range)

p2.scatter(x, y, radius=radii,
           fill_color=colors, fill_alpha=0.6,
           line_color=None)

show(p2)
# Out:
#   <div class="bk-root" id="11294eba-ee3b-4093-ad06-57ffe51dda76" data-root-id="1662"></div>

# %%
from bokeh.plotting import gridplot

p = gridplot([[p1], [p2]], toolbar_location="above")

# show the results
show(p)
# Out:
#   <div class="bk-root" id="a49755a1-d9e1-4b5a-b2eb-fabef91c4d7d" data-root-id="1894"></div>

# %% [markdown]
# ## Code blocks and outputs
#
# Jupyter Book will also embed your code blocks and output in your book.
# For example, here's some sample Matplotlib code:

# %%
# %matplotlib inline

# %%
from matplotlib import rcParams, cycler
import matplotlib.pyplot as plt
import numpy as np
plt.ion()

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

N = 10
data = [np.logspace(0, 1, 100) + np.random.randn(100) + ii for ii in range(N)]
data = np.array(data).T
cmap = plt.cm.coolwarm
rcParams['axes.prop_cycle'] = cycler(color=cmap(np.linspace(0, 1, N)))


from matplotlib.lines import Line2D
custom_lines = [Line2D([0], [0], color=cmap(0.), lw=4),
                Line2D([0], [0], color=cmap(.5), lw=4),
                Line2D([0], [0], color=cmap(1.), lw=4)]

fig, ax = plt.subplots(figsize=(15, 5))
lines = ax.plot(data)
ax.legend(custom_lines, ['Cold', 'Medium', 'Hot']);

# %% [markdown]
# There is a lot more that you can do with outputs (such as including interactive outputs)
# with your book. For more information about this, see [the Jupyter Book documentation](https://jupyterbook.org)
